# %% [markdown]
# ### How To Break Into the Field
#
# Now you have had a closer look at the data, and you saw how I approached looking at how the survey respondents think you should break into the field.  Let's recreate those results, as well as take a look at another question.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import HowToBreakIntoTheField as t
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
schema = pd.read_csv('./survey_results_schema.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize       ...       StackOverflowMakeMoney Gender  \
# 0                       NaN       ...            Strongly disagree   Male
# 1        20 to 99 employees       ...            Strongly disagree   Male
# 2  10,000 or more employees       ...                     Disagree   Male
# 3  10,000 or more employees       ...                     Disagree   Male
# 4        10 to 19 employees       ...                          NaN    NaN
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 1       A master's degree  White or of European descent     Somewhat agree
# 2   A professional degree  White or of European descent     Somewhat agree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 0       Strongly agree           Disagree    Strongly agree       NaN
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
# 4                  NaN                NaN               NaN       NaN
#
#    ExpectedSalary
# 0             NaN
# 1         37500.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 154 columns]

# %% [markdown]
# #### Question 1
#
# **1.** In order to understand how to break into the field, we will look at the **CousinEducation** field.  Use the **schema** dataset to answer this question.  Write a function called **get_description** that takes the **schema dataframe** and the **column** as a string, and returns a string of the description for that column.

# %%
schema.head()
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...
# 3       Country            In which country do you currently live?
# 4    University  Are you currently enrolled in a formal, degree...

# %%
def get_description(column_name, schema=schema):
    '''
    INPUT - schema - pandas dataframe with the schema of the developers survey
            column_name - string - the name of the column you would like to know about
    OUTPUT - 
            desc - string - the description of the column
    '''
    desc = list(schema[schema["Column"] == column_name]['Question'])[0]
    return desc

#test your code
#Check your function against solution - you shouldn't need to change any of the below code
get_description(df.columns[0]) # This should return a string of the first column description
# Out:
# 'Respondent ID number'

# %%
#Check your function against solution - you shouldn't need to change any of the below code
descrips = set(get_description(col) for col in df.columns)
t.check_description(descrips)
# Out:
# Nice job it looks like your function works correctly!

# %% [markdown]
# The question we have been focused on has been around how to break into the field.  Use your **get_description** function below to take a closer look at the **CousinEducation** column.

# %%
get_description('CousinEducation')
# Out:
# "Let's pretend you have a distant cousin. They are 24 years old, have a college degree in a field not related to computer programming, and have been working a non-coding job for the last two years. They want your advice on how to switch to a career as a software developer. Which of the following options would you most strongly recommend to your cousin?\nLet's pretend you have a distant cousin named Robert. He is 24 years old, has a college degree in a field not related to computer programming, and has been working a non-coding job for the last two years. He wants your advice on how to switch to a career as a software developer. Which of the following options would you most strongly recommend to Robert?\nLet's pretend you have a distant cousin named Alice. She is 24 years old, has a college degree in a field not related to computer programming, and has been working a non-coding job for the last two years. She wants your advice on how to switch to a career as a software developer. Which of the following options would you most strongly recommend to Alice?"

# %% [markdown]
# #### Question 2
#
# **2.** Provide a pandas series of the different **CousinEducation** status values in the dataset.  Store this pandas series in **cous_ed_vals**.  If you are correct, you should see a bar chart of the proportion of individuals in each status.  If it looks terrible, and you get no information from it, then you followed directions.  However, we should clean this up!

# %%
cous_ed_vals = df['CousinEducation'].value_counts()  #Provide a pandas series of the counts for each CousinEducation status

cous_ed_vals # assure this looks right
# Out:
# Take online courses; Buy books and work through the exercises                                                                          192
# None of these                                                                                                                          167
# Take online courses                                                                                                                    158
# Take online courses; Part-time/evening courses; Buy books and work through the exercises                                               140
# Take online courses; Bootcamp; Part-time/evening courses; Buy books and work through the exercises                                     132
# Take online courses; Contribute to open source; Buy books and work through the exercises                                               129
# Return to college; Take online courses; Part-time/evening courses; Buy books and work through the exercises                            121
# Take online courses; Contribute to open source; Buy books and work through the exercises; Conferences/meet-ups                         115
# Take online courses; Contribute to open source; Part-time/evening courses; Buy books and work through the exercises                     95
# Other                                                                                                                                   91
# Buy books and work through the exercises                                                                                                89
# Take online courses; Contribute to open source; Participate in online coding competitions; Buy books and work through the exercises     86
# Take online courses; Part-time/evening courses; Buy books and work through the exercises; Conferences/meet-ups                          82
# Return to college                                                                                                                       79
# Get a job as a QA tester; Take online courses; Part-time/evening courses; Buy books and work through the exercises                      78
# Take online courses; Buy books and work through the exercises; Conferences/meet-ups                                                     74
# Take online courses; Bootcamp; Part-time/evening courses                                                                                68
# Return to college; Take online courses; Buy books and work through the exercises                                                        66
# Take online courses; Part-time/evening courses; Participate in online coding competitions; Buy books and work through the exercises     64
# Take online courses; Contribute to open source                                                                                          63
# Contribute to open source; Buy books and work through the exercises                                                                     62
# Take online courses; Part-time/evening courses                                                                                          60
# Take online courses; Bootcamp; Buy books and work through the exercises                                                                 59
# Return to college; Take online courses                                                                                                  55
# Take online courses; Contribute to open source; Bootcamp; Buy books and work through the exercises                                      51
# Contribute to open source                                                                                                               51
# Take online courses; Bootcamp                                                                                                           49
# Return to college; Take online courses; Bootcamp; Part-time/evening courses                                                             49
# Return to college; Master's degree; Take online courses; Buy books and work through the exercises                                       47
# Get a job as a QA tester; Take online courses; Buy books and work through the exercises                                                 46
#                                                                                                                                       ...
# Buy books and work through the exercises; Conferences/meet-ups; Other                                                                    1
# Get a job as a QA tester; Contribute to open source; Buy books and work through the exercises; Other                                     1
# Return to college; Master's degree; Participate in online coding competitions; Conferences/meet-ups                                      1
# Participate in hackathons; Participate in online coding competitions; Conferences/meet-ups                                               1
# Get a job as a QA tester; Participate in hackathons; Buy books and work through the exercises; Other                                     1
# Return to college; Master's degree; Part-time/evening courses; Other                                                                     1
# Return to college; Participate in online coding competitions; Conferences/meet-ups                                                       1
# Return to college; Get a job as a QA tester; Take online courses; Other                                                                  1
# Master's degree; Take online courses; Participate in hackathons                                                                          1
# Master's degree; Bootcamp; Participate in hackathons; Participate in online coding competitions                                          1
# Contribute to open source; Participate in online coding competitions; Other                                                              1
# Master's degree; Part-time/evening courses; Participate in hackathons; Participate in online coding competitions                         1
# Return to college; Get a job as a QA tester; Participate in online coding competitions; Buy books and work through the exercises         1
# Part-time/evening courses; Participate in online coding competitions; Buy books and work through the exercises; Other                    1
# Return to college; Master's degree; Get a job as a QA tester; Conferences/meet-ups                                                       1
# Get a job as a QA tester; Contribute to open source; Participate in online coding competitions; Other                                    1
# Get a job as a QA tester; Conferences/meet-ups; Other                                                                                    1
# Bootcamp; Part-time/evening courses; Buy books and work through the exercises; Other                                                     1
# Participate in online coding competitions; Other                                                                                         1
# Return to college; Contribute to open source; Participate in online coding competitions; Conferences/meet-ups                            1
# Get a job as a QA tester; Part-time/evening courses; Participate in hackathons; Conferences/meet-ups                                     1
# Master's degree; Bootcamp; Part-time/evening courses; Participate in online coding competitions                                          1
# Master's degree; Get a job as a QA tester; Participate in hackathons; Buy books and work through the exercises                           1
# Get a job as a QA tester; Bootcamp; Participate in online coding competitions; Conferences/meet-ups                                      1
# Master's degree; Part-time/evening courses; Participate in hackathons; Buy books and work through the exercises                          1
# Return to college; Master's degree; Participate in hackathons; Conferences/meet-ups                                                      1
# Get a job as a QA tester; Bootcamp; Participate in hackathons                                                                            1
# Master's degree; Bootcamp; Participate in hackathons                                                                                     1
# Contribute to open source; Part-time/evening courses; Conferences/meet-ups; Other                                                        1
# Master's degree; Bootcamp; Part-time/evening courses; Participate in hackathons                                                          1
# Name: CousinEducation, Length: 601, dtype: int64

# %%
# The below should be a bar chart of the proportion of individuals in your ed_vals
# if it is set up correctly.

(cous_ed_vals/df.shape[0]).plot(kind="bar");
plt.title("Formal Education");

# %% [markdown]
# We definitely need to clean this.  Above is an example of what happens when you do not clean your data. Below I am using the same code you saw in the earlier video to take a look at the data after it has been cleaned.

# %%
df['CousinEducation'].value_counts().reset_index()
# Out:
#                                                  index  CousinEducation
# 0    Take online courses; Buy books and work throug...              192
# 1                                        None of these              167
# 2                                  Take online courses              158
# 3    Take online courses; Part-time/evening courses...              140
# 4    Take online courses; Bootcamp; Part-time/eveni...              132
# 5    Take online courses; Contribute to open source...              129
# 6    Return to college; Take online courses; Part-t...              121
# 7    Take online courses; Contribute to open source...              115
# 8    Take online courses; Contribute to open source...               95
# 9                                                Other               91
# 10            Buy books and work through the exercises               89
# 11   Take online courses; Contribute to open source...               86
# 12   Take online courses; Part-time/evening courses...               82
# 13                                   Return to college               79
# 14   Get a job as a QA tester; Take online courses;...               78
# 15   Take online courses; Buy books and work throug...               74
# 16   Take online courses; Bootcamp; Part-time/eveni...               68
# 17   Return to college; Take online courses; Buy bo...               66
# 18   Take online courses; Part-time/evening courses...               64
# 19      Take online courses; Contribute to open source               63
# 20   Contribute to open source; Buy books and work ...               62
# 21      Take online courses; Part-time/evening courses               60
# 22   Take online courses; Bootcamp; Buy books and w...               59
# 23              Return to college; Take online courses               55
# 24   Take online courses; Contribute to open source...               51
# 25                           Contribute to open source               51
# 26                       Take online courses; Bootcamp               49
# 27   Return to college; Take online courses; Bootca...               49
# 28   Return to college; Master's degree; Take onlin...               47
# 29   Get a job as a QA tester; Take online courses;...               46
# ..                                                 ...              ...
# 571  Buy books and work through the exercises; Conf...                1
# 572  Get a job as a QA tester; Contribute to open s...                1
# 573  Return to college; Master's degree; Participat...                1
# 574  Participate in hackathons; Participate in onli...                1
# 575  Get a job as a QA tester; Participate in hacka...                1
# 576  Return to college; Master's degree; Part-time/...                1
# 577  Return to college; Participate in online codin...                1
# 578  Return to college; Get a job as a QA tester; T...                1
# 579  Master's degree; Take online courses; Particip...                1
# 580  Master's degree; Bootcamp; Participate in hack...                1
# 581  Contribute to open source; Participate in onli...                1
# 582  Master's degree; Part-time/evening courses; Pa...                1
# 583  Return to college; Get a job as a QA tester; P...                1
# 584  Part-time/evening courses; Participate in onli...                1
# 585  Return to college; Master's degree; Get a job ...                1
# 586  Get a job as a QA tester; Contribute to open s...                1
# 587  Get a job as a QA tester; Conferences/meet-ups...                1
# 588  Bootcamp; Part-time/evening courses; Buy books...                1
# 589   Participate in online coding competitions; Other                1
# 590  Return to college; Contribute to open source; ...                1
# 591  Get a job as a QA tester; Part-time/evening co...                1
# 592  Master's degree; Bootcamp; Part-time/evening c...                1
# 593  Master's degree; Get a job as a QA tester; Par...                1
# 594  Get a job as a QA tester; Bootcamp; Participat...                1
# 595  Master's degree; Part-time/evening courses; Pa...                1
# 596  Return to college; Master's degree; Participat...                1
# 597  Get a job as a QA tester; Bootcamp; Participat...                1
# 598  Master's degree; Bootcamp; Participate in hack...                1
# 599  Contribute to open source; Part-time/evening c...                1
# 600  Master's degree; Bootcamp; Part-time/evening c...                1
#
# [601 rows x 2 columns]

# %%
possible_vals = ["Take online courses", "Buy books and work through the exercises", 
                 "None of these", "Part-time/evening courses", "Return to college",
                 "Contribute to open source", "Conferences/meet-ups", "Bootcamp",
                 "Get a job as a QA tester", "Participate in online coding competitions",
                 "Master's degree", "Participate in hackathons", "Other"]

def clean_and_plot(df, title='Method of Educating Suggested', plot=True):
    '''
    INPUT 
        df - a dataframe holding the CousinEducation column
        title - string the title of your plot
        axis - axis object
        plot - bool providing whether or not you want a plot back
        
    OUTPUT
        study_df - a dataframe with the count of how many individuals
        Displays a plot of pretty things related to the CousinEducation column.
    '''
    study = df['CousinEducation'].value_counts().reset_index()
    study.rename(columns={'index': 'method', 'CousinEducation': 'count'}, inplace=True)
    study_df = t.total_count(study, 'method', 'count', possible_vals)

    study_df.set_index('method', inplace=True)
    if plot:
        (study_df/study_df.sum()).plot(kind='bar', legend=None);
        plt.title(title);
        plt.show()
    props_study_df = study_df/study_df.sum()
    return props_study_df
    
props_df = clean_and_plot(df)

# %% [markdown]
# #### Question 3
#
# **3.** I wonder if some of the individuals might have bias towards their own degrees.  Complete the function below that will apply to the elements of the **FormalEducation** column in **df**.

# %%
def higher_ed(formal_ed_str):
    '''
    INPUT
        formal_ed_str - a string of one of the values from the Formal Education column
    
    OUTPUT
        return 1 if the string is  in ("Master's degree", "Doctoral", "Professional degree")
        return 0 otherwise
    
    '''
    
    if (formal_ed_str in ["Master's degree", "Doctoral", "Professional degree"]):
        return 1
    else:
        return 0


df["FormalEducation"].apply(higher_ed)[:5] #Test your function to assure it provides 1 and 0 values for the df
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: FormalEducation, dtype: int64

# %%
# Check your code here
df['HigherEd'] = df["FormalEducation"].apply(higher_ed)
higher_ed_perc = df['HigherEd'].mean()
t.higher_ed_test(higher_ed_perc)
# Out:
# Nice job!  That's right.  The percentage of individuals in these three groups is 0.2302376714480159.

# %% [markdown]
# #### Question 4
#
# **4.** Now we would like to find out if the proportion of individuals who completed one of these three programs feel differently than those that did not. Store a dataframe of only the individual's who had **HigherEd** equal to 1 in **ed_1**.  Similarly, store a dataframe of only the **HigherEd** equal to 0 values in **ed_0**.
#
# Notice, you have already created the **HigherEd** column using the check code portion above, so here you only need to subset the dataframe using this newly created column.

# %%
df[df['HigherEd'] == 1]
# Out:
#        Respondent                                       Professional  \
# 4               5                             Professional developer
# 6               7  Professional non-developer who sometimes write...
# 7               8                             Professional developer
# 9              10                             Professional developer
# 14             15                             Professional developer
# 24             25                             Professional developer
# 25             26                             Professional developer
# 32             33                                      None of these
# 35             36                             Professional developer
# 41             42                             Professional developer
# 42             43                             Professional developer
# 51             52                             Professional developer
# 54             55                             Professional developer
# 57             58                             Professional developer
# 59             60                             Professional developer
# 62             63                             Professional developer
# 63             64                             Professional developer
# 64             65                             Professional developer
# 73             74                             Professional developer
# 75             76                             Professional developer
# 86             87                             Professional developer
# 91             92                             Professional developer
# 92             93                             Professional developer
# 99            100                             Professional developer
# 102           103                             Professional developer
# 107           108                             Professional developer
# 108           109                             Professional developer
# 126           127                             Professional developer
# 144           145                             Professional developer
# 145           146                             Professional developer
# ...           ...                                                ...
# 19004       19005                             Professional developer
# 19007       19008                             Professional developer
# 19008       19009                             Professional developer
# 19009       19010                             Professional developer
# 19010       19011                Used to be a professional developer
# 19011       19012                             Professional developer
# 19013       19014  Professional non-developer who sometimes write...
# 19018       19019                             Professional developer
# 19023       19024                             Professional developer
# 19027       19028                                            Student
# 19031       19032  Professional non-developer who sometimes write...
# 19032       19033                             Professional developer
# 19035       19036                             Professional developer
# 19046       19047                             Professional developer
# 19049       19050                             Professional developer
# 19051       19052  Professional non-developer who sometimes write...
# 19055       19056                             Professional developer
# 19059       19060                             Professional developer
# 19063       19064  Professional non-developer who sometimes write...
# 19064       19065                             Professional developer
# 19067       19068                             Professional developer
# 19071       19072                             Professional developer
# 19072       19073                             Professional developer
# 19073       19074                             Professional developer
# 19077       19078                             Professional developer
# 19086       19087                             Professional developer
# 19087       19088                             Professional developer
# 19091       19092                             Professional developer
# 19096       19097                             Professional developer
# 19101       19102                             Professional developer
#
#                                     ProgramHobby         Country  \
# 4                      Yes, I program as a hobby     Switzerland
# 6                                      Yes, both   United States
# 7                                      Yes, both          Poland
# 9                      Yes, I program as a hobby          France
# 14                     Yes, I program as a hobby  United Kingdom
# 24                     Yes, I program as a hobby         Belgium
# 25                     Yes, I program as a hobby   United States
# 32     Yes, I contribute to open source projects         Germany
# 35                     Yes, I program as a hobby           Italy
# 41                     Yes, I program as a hobby         Denmark
# 42                     Yes, I program as a hobby         Ukraine
# 51                                            No   United States
# 54                                            No         Germany
# 57                                     Yes, both           Italy
# 59     Yes, I contribute to open source projects          Poland
# 62                                     Yes, both         Ukraine
# 63                                            No  United Kingdom
# 64                                            No     Netherlands
# 73                     Yes, I program as a hobby         Austria
# 75                                     Yes, both          France
# 86                                            No         Germany
# 91                                     Yes, both         Germany
# 92                     Yes, I program as a hobby   United States
# 99                                     Yes, both   United States
# 102                                    Yes, both         Germany
# 107                    Yes, I program as a hobby           India
# 108                                           No  United Kingdom
# 126                    Yes, I program as a hobby         Estonia
# 144                    Yes, I program as a hobby         Ukraine
# 145                    Yes, I program as a hobby         Croatia
# ...                                          ...             ...
# 19004  Yes, I contribute to open source projects         Ukraine
# 19007                                         No          France
# 19008                                  Yes, both  United Kingdom
# 19009                  Yes, I program as a hobby   United States
# 19010  Yes, I contribute to open source projects          France
# 19011                  Yes, I program as a hobby     South Korea
# 19013                                         No   United States
# 19018                                         No          France
# 19023                                         No   United States
# 19027                  Yes, I program as a hobby  Czech Republic
# 19031                  Yes, I program as a hobby         Hungary
# 19032                  Yes, I program as a hobby         Germany
# 19035                                  Yes, both          Turkey
# 19046                                  Yes, both  United Kingdom
# 19049                  Yes, I program as a hobby         Germany
# 19051                  Yes, I program as a hobby         Germany
# 19055                                  Yes, both   United States
# 19059                  Yes, I program as a hobby       Argentina
# 19063                  Yes, I program as a hobby          France
# 19064  Yes, I contribute to open source projects          France
# 19067                  Yes, I program as a hobby          France
# 19071                  Yes, I program as a hobby          Greece
# 19072                                         No          France
# 19073                  Yes, I program as a hobby  United Kingdom
# 19077                  Yes, I program as a hobby          France
# 19086                                         No         Germany
# 19087                  Yes, I program as a hobby           Spain
# 19091                                         No          Sweden
# 19096                                         No          France
# 19101                  Yes, I program as a hobby          France
#
#            University                                   EmploymentStatus  \
# 4                  No                                 Employed full-time
# 6                  No                                 Employed full-time
# 7                  No                                 Employed full-time
# 9      Yes, full-time  Independent contractor, freelancer, or self-em...
# 14                 No                                 Employed full-time
# 24                 No                                 Employed full-time
# 25                 No                                 Employed full-time
# 32     Yes, full-time  Independent contractor, freelancer, or self-em...
# 35                 No                                 Employed full-time
# 41                 No  Independent contractor, freelancer, or self-em...
# 42                 No                                 Employed full-time
# 51                 No                                 Employed full-time
# 54                 No                                 Employed full-time
# 57                 No                                 Employed full-time
# 59                 No                                 Employed full-time
# 62                 No  Independent contractor, freelancer, or self-em...
# 63                 No                                 Employed full-time
# 64                 No                                 Employed full-time
# 73                 No                                 Employed full-time
# 75                 No                                 Employed full-time
# 86                 No                                 Employed full-time
# 91                 No             Not employed, and not looking for work
# 92                 No                                 Employed full-time
# 99                 No                                 Employed full-time
# 102                No                                 Employed full-time
# 107                No                                 Employed full-time
# 108                No                                 Employed full-time
# 126                No                                 Employed full-time
# 144                No                                 Employed full-time
# 145                No                                 Employed full-time
# ...               ...                                                ...
# 19004              No                                 Employed full-time
# 19007              No                                 Employed full-time
# 19008  Yes, full-time                                 Employed full-time
# 19009              No                                 Employed full-time
# 19010              No                                 Employed full-time
# 19011              No                                 Employed full-time
# 19013              No                                 Employed full-time
# 19018  Yes, part-time                                 Employed full-time
# 19023              No                                 Employed full-time
# 19027              No                                 Employed full-time
# 19031              No                                 Employed full-time
# 19032              No                                 Employed full-time
# 19035  Yes, part-time                                 Employed full-time
# 19046              No                                 Employed full-time
# 19049              No  Independent contractor, freelancer, or self-em...
# 19051  Yes, part-time                                 Employed part-time
# 19055              No                                 Employed full-time
# 19059  Yes, full-time                                 Employed full-time
# 19063  Yes, part-time                                 Employed part-time
# 19064              No                                 Employed full-time
# 19067              No                                 Employed full-time
# 19071              No                                 Employed full-time
# 19072              No                                 Employed full-time
# 19073              No                                 Employed full-time
# 19077              No                                 Employed full-time
# 19086  Yes, part-time                                 Employed full-time
# 19087              No                                 Employed full-time
# 19091              No                                 Employed full-time
# 19096              No                                 Employed full-time
# 19101              No                                 Employed full-time
#
#            FormalEducation                                     MajorUndergrad  \
# 4          Master's degree           Computer science or software engineering
# 6          Master's degree      A non-computer-focused engineering discipline
# 7          Master's degree           Computer science or software engineering
# 9          Master's degree           Computer science or software engineering
# 14     Professional degree  Computer engineering or electrical/electronics...
# 24         Master's degree           Computer science or software engineering
# 25         Master's degree           Computer science or software engineering
# 32     Professional degree           Computer science or software engineering
# 35         Master's degree           Computer science or software engineering
# 41         Master's degree           Computer science or software engineering
# 42         Master's degree            Computer programming or Web development
# 51         Master's degree           Computer science or software engineering
# 54         Master's degree           Computer science or software engineering
# 57         Master's degree           Computer science or software engineering
# 59         Master's degree  Computer engineering or electrical/electronics...
# 62         Master's degree                           I never declared a major
# 63         Master's degree                                     Something else
# 64         Master's degree           Computer science or software engineering
# 73         Master's degree           Computer science or software engineering
# 75         Master's degree                          Mathematics or statistics
# 86         Master's degree           Computer science or software engineering
# 91         Master's degree           Computer science or software engineering
# 92         Master's degree           Computer science or software engineering
# 99         Master's degree           Computer science or software engineering
# 102        Master's degree  Computer engineering or electrical/electronics...
# 107        Master's degree                                  A natural science
# 108        Master's degree           Computer science or software engineering
# 126        Master's degree  Computer engineering or electrical/electronics...
# 144        Master's degree                                                NaN
# 145        Master's degree  Computer engineering or electrical/electronics...
# ...                    ...                                                ...
# 19004      Master's degree           Computer science or software engineering
# 19007      Master's degree      A non-computer-focused engineering discipline
# 19008      Master's degree           Computer science or software engineering
# 19009      Master's degree           Computer science or software engineering
# 19010      Master's degree           Computer science or software engineering
# 19011      Master's degree           Computer science or software engineering
# 19013      Master's degree                                  A natural science
# 19018      Master's degree           Computer science or software engineering
# 19023      Master's degree           Computer science or software engineering
# 19027      Master's degree                              A business discipline
# 19031      Master's degree           Computer science or software engineering
# 19032      Master's degree                           I never declared a major
# 19035      Master's degree           Computer science or software engineering
# 19046      Master's degree  Computer engineering or electrical/electronics...
# 19049      Master's degree           Computer science or software engineering
# 19051      Master's degree           Computer science or software engineering
# 19055      Master's degree           Computer science or software engineering
# 19059      Master's degree                          Mathematics or statistics
# 19063      Master's degree                     Management information systems
# 19064      Master's degree      A non-computer-focused engineering discipline
# 19067      Master's degree           Computer science or software engineering
# 19071      Master's degree                                  A natural science
# 19072      Master's degree           Computer science or software engineering
# 19073      Master's degree           Computer science or software engineering
# 19077      Master's degree           Computer science or software engineering
# 19086  Professional degree                     Management information systems
# 19087  Professional degree            Computer programming or Web development
# 19091      Master's degree           Computer science or software engineering
# 19096      Master's degree           Computer science or software engineering
# 19101      Master's degree           Computer science or software engineering
#
#                                               HomeRemote  \
# 4                                                  Never
# 6      Less than half the time, but at least one day ...
# 7      All or almost all the time (I'm full-time remote)
# 9                                       It's complicated
# 14     All or almost all the time (I'm full-time remote)
# 24                                                 Never
# 25     Less than half the time, but at least one day ...
# 32                                                   NaN
# 35                                                 Never
# 41                                 A few days each month
# 42                                                 Never
# 51     Less than half the time, but at least one day ...
# 54                                 A few days each month
# 57                                 A few days each month
# 59                                                 Never
# 62     All or almost all the time (I'm full-time remote)
# 63                                 A few days each month
# 64                                 A few days each month
# 73                                                 Never
# 75                                                 Never
# 86                                   About half the time
# 91                                                   NaN
# 92                                 A few days each month
# 99                                                 Never
# 102                                A few days each month
# 107                                A few days each month
# 108                                A few days each month
# 126                                A few days each month
# 144                                A few days each month
# 145                                                Never
# ...                                                  ...
# 19004  Less than half the time, but at least one day ...
# 19007                                              Never
# 19008                              A few days each month
# 19009                              A few days each month
# 19010                                              Never
# 19011                                   It's complicated
# 19013                                              Never
# 19018                              A few days each month
# 19023                                              Never
# 19027                              A few days each month
# 19031                                              Never
# 19032                                              Never
# 19035                              A few days each month
# 19046                              A few days each month
# 19049              More than half, but not all, the time
# 19051                              A few days each month
# 19055                              A few days each month
# 19059                                              Never
# 19063                                   It's complicated
# 19064                              A few days each month
# 19067                                              Never
# 19071                                              Never
# 19072                              A few days each month
# 19073              More than half, but not all, the time
# 19077                                About half the time
# 19086                              A few days each month
# 19087                                              Never
# 19091                                              Never
# 19096                                              Never
# 19101  All or almost all the time (I'm full-time remote)
#
#                     CompanySize    ...     Gender  \
# 4            10 to 19 employees    ...        NaN
# 6            20 to 99 employees    ...       Male
# 7       Fewer than 10 employees    ...       Male
# 9                           NaN    ...       Male
# 14     5,000 to 9,999 employees    ...       Male
# 24           20 to 99 employees    ...        NaN
# 25     10,000 or more employees    ...       Male
# 32                          NaN    ...       Male
# 35      Fewer than 10 employees    ...       Male
# 41                          NaN    ...        NaN
# 42         100 to 499 employees    ...       Male
# 51     10,000 or more employees    ...       Male
# 54     1,000 to 4,999 employees    ...       Male
# 57         100 to 499 employees    ...       Male
# 59         500 to 999 employees    ...        NaN
# 62                          NaN    ...       Male
# 63         100 to 499 employees    ...        NaN
# 64     10,000 or more employees    ...       Male
# 73         500 to 999 employees    ...       Male
# 75         500 to 999 employees    ...       Male
# 86         100 to 499 employees    ...        NaN
# 91                          NaN    ...       Male
# 92     10,000 or more employees    ...        NaN
# 99           20 to 99 employees    ...       Male
# 102          20 to 99 employees    ...       Male
# 107          20 to 99 employees    ...       Male
# 108                I don't know    ...       Male
# 126          20 to 99 employees    ...       Male
# 144    5,000 to 9,999 employees    ...        NaN
# 145          10 to 19 employees    ...        NaN
# ...                         ...    ...        ...
# 19004  10,000 or more employees    ...       Male
# 19007  10,000 or more employees    ...       Male
# 19008  5,000 to 9,999 employees    ...        NaN
# 19009  5,000 to 9,999 employees    ...       Male
# 19010      100 to 499 employees    ...        NaN
# 19011        10 to 19 employees    ...       Male
# 19013      100 to 499 employees    ...     Female
# 19018      500 to 999 employees    ...        NaN
# 19023  1,000 to 4,999 employees    ...       Male
# 19027        20 to 99 employees    ...       Male
# 19031   Fewer than 10 employees    ...       Male
# 19032      500 to 999 employees    ...        NaN
# 19035  10,000 or more employees    ...        NaN
# 19046  5,000 to 9,999 employees    ...       Male
# 19049                       NaN    ...       Male
# 19051        20 to 99 employees    ...       Male
# 19055  10,000 or more employees    ...       Male
# 19059      100 to 499 employees    ...        NaN
# 19063  10,000 or more employees    ...        NaN
# 19064   Fewer than 10 employees    ...       Male
# 19067        10 to 19 employees    ...       Male
# 19071      100 to 499 employees    ...        NaN
# 19072        10 to 19 employees    ...        NaN
# 19073   Fewer than 10 employees    ...        NaN
# 19077        10 to 19 employees    ...        NaN
# 19086      100 to 499 employees    ...       Male
# 19087        10 to 19 employees    ...        NaN
# 19091      100 to 499 employees    ...       Male
# 19096        20 to 99 employees    ...       Male
# 19101      100 to 499 employees    ...        NaN
#
#                                  HighestEducationParents  \
# 4                                                    NaN
# 6                                      A doctoral degree
# 7                                      A master's degree
# 9                                      A doctoral degree
# 14                                           High school
# 24                                                   NaN
# 25                                     A master's degree
# 32                                 A professional degree
# 35                                     A master's degree
# 41                                                   NaN
# 42                                     A master's degree
# 51                                     A master's degree
# 54                                     A master's degree
# 57                             Primary/elementary school
# 59                                                   NaN
# 62                                     A master's degree
# 63                                                   NaN
# 64                                     A doctoral degree
# 73                             Primary/elementary school
# 75                                     A master's degree
# 86                                                   NaN
# 91                                     A master's degree
# 92                                                   NaN
# 99                                     A master's degree
# 102                                    A master's degree
# 107                                  A bachelor's degree
# 108                            Primary/elementary school
# 126                                    A master's degree
# 144                                                  NaN
# 145                                                  NaN
# ...                                                  ...
# 19004                                  A master's degree
# 19007                                        High school
# 19008                                                NaN
# 19009  Some college/university study, no bachelor's d...
# 19010                                                NaN
# 19011                             I prefer not to answer
# 19013                              A professional degree
# 19018                                                NaN
# 19023                                  A master's degree
# 19027                                  A master's degree
# 19031                                        High school
# 19032                                                NaN
# 19035                                                NaN
# 19046                                  A master's degree
# 19049                                  A master's degree
# 19051                                        High school
# 19055                              A professional degree
# 19059                                                NaN
# 19063                                                NaN
# 19064                              A professional degree
# 19067  Some college/university study, no bachelor's d...
# 19071                                                NaN
# 19072                                                NaN
# 19073                                                NaN
# 19077                                                NaN
# 19086                              A professional degree
# 19087                                                NaN
# 19091                                  A master's degree
# 19096                                        High school
# 19101                                                NaN
#
#                                                     Race      SurveyLong  \
# 4                                                    NaN             NaN
# 6                           White or of European descent        Disagree
# 7                           White or of European descent           Agree
# 9                           White or of European descent  Somewhat agree
# 14                          White or of European descent  Somewhat agree
# 24                                                   NaN             NaN
# 25                          White or of European descent        Disagree
# 32                          White or of European descent  Somewhat agree
# 35                          White or of European descent  Somewhat agree
# 41                                                   NaN             NaN
# 42                          White or of European descent  Somewhat agree
# 51                          White or of European descent           Agree
# 54     Hispanic or Latino/Latina; White or of Europea...  Strongly agree
# 57                          White or of European descent        Disagree
# 59                                                   NaN             NaN
# 62                          White or of European descent           Agree
# 63                                                   NaN             NaN
# 64                          White or of European descent  Strongly agree
# 73                          White or of European descent  Strongly agree
# 75                          White or of European descent        Disagree
# 86                                                   NaN             NaN
# 91                          White or of European descent        Disagree
# 92                                                   NaN             NaN
# 99                          White or of European descent           Agree
# 102                         White or of European descent  Somewhat agree
# 107                                          South Asian        Disagree
# 108                         White or of European descent  Strongly agree
# 126                         White or of European descent  Somewhat agree
# 144                                                  NaN             NaN
# 145                                                  NaN             NaN
# ...                                                  ...             ...
# 19004                       White or of European descent  Strongly agree
# 19007                                I prefer not to say        Disagree
# 19008                                                NaN             NaN
# 19009                       White or of European descent           Agree
# 19010                                                NaN             NaN
# 19011                                         East Asian  Strongly agree
# 19013                       White or of European descent  Somewhat agree
# 19018                                                NaN             NaN
# 19023                                        South Asian           Agree
# 19027                       White or of European descent        Disagree
# 19031                       White or of European descent  Strongly agree
# 19032                                                NaN             NaN
# 19035                                                NaN             NaN
# 19046                       White or of European descent  Somewhat agree
# 19049                       White or of European descent  Strongly agree
# 19051                       White or of European descent           Agree
# 19055                                        South Asian           Agree
# 19059                                                NaN             NaN
# 19063                                                NaN             NaN
# 19064                                I prefer not to say           Agree
# 19067                       White or of European descent           Agree
# 19071                                                NaN             NaN
# 19072                                                NaN             NaN
# 19073                                                NaN             NaN
# 19077                                                NaN             NaN
# 19086                       White or of European descent  Strongly agree
# 19087                                                NaN             NaN
# 19091                       White or of European descent        Disagree
# 19096                       White or of European descent  Strongly agree
# 19101                                                NaN             NaN
#
#       QuestionsInteresting QuestionsConfusing InterestedAnswers  \
# 4                      NaN                NaN               NaN
# 6                    Agree           Disagree             Agree
# 7           Somewhat agree           Disagree             Agree
# 9                    Agree           Disagree             Agree
# 14                   Agree           Disagree             Agree
# 24                     NaN                NaN               NaN
# 25          Strongly agree           Disagree    Strongly agree
# 32          Somewhat agree  Strongly disagree             Agree
# 35                   Agree           Disagree    Strongly agree
# 41                     NaN                NaN               NaN
# 42                   Agree  Strongly disagree             Agree
# 51          Somewhat agree  Strongly disagree    Strongly agree
# 54                Disagree  Strongly disagree             Agree
# 57                   Agree           Disagree             Agree
# 59                     NaN                NaN               NaN
# 62          Somewhat agree           Disagree    Strongly agree
# 63                     NaN                NaN               NaN
# 64          Somewhat agree           Disagree             Agree
# 73                Disagree           Disagree    Strongly agree
# 75                   Agree           Disagree             Agree
# 86                     NaN                NaN               NaN
# 91          Somewhat agree  Strongly disagree    Somewhat agree
# 92                     NaN                NaN               NaN
# 99          Somewhat agree              Agree    Strongly agree
# 102         Somewhat agree           Disagree             Agree
# 107                  Agree           Disagree    Strongly agree
# 108                  Agree           Disagree             Agree
# 126         Somewhat agree           Disagree             Agree
# 144                    NaN                NaN               NaN
# 145                    NaN                NaN               NaN
# ...                    ...                ...               ...
# 19004       Somewhat agree           Disagree    Strongly agree
# 19007                Agree           Disagree             Agree
# 19008                  NaN                NaN               NaN
# 19009       Somewhat agree           Disagree    Somewhat agree
# 19010                  NaN                NaN               NaN
# 19011    Strongly disagree           Disagree             Agree
# 19013       Somewhat agree           Disagree             Agree
# 19018                  NaN                NaN               NaN
# 19023       Somewhat agree           Disagree             Agree
# 19027                Agree  Strongly disagree    Somewhat agree
# 19031                Agree           Disagree    Somewhat agree
# 19032                  NaN                NaN               NaN
# 19035                  NaN                NaN               NaN
# 19046                Agree  Strongly disagree    Strongly agree
# 19049       Strongly agree     Somewhat agree    Strongly agree
# 19051       Somewhat agree  Strongly disagree    Somewhat agree
# 19055       Somewhat agree           Disagree    Strongly agree
# 19059                  NaN                NaN               NaN
# 19063                  NaN                NaN               NaN
# 19064                Agree  Strongly disagree    Strongly agree
# 19067                Agree     Somewhat agree    Strongly agree
# 19071                  NaN                NaN               NaN
# 19072                  NaN                NaN               NaN
# 19073                  NaN                NaN               NaN
# 19077                  NaN                NaN               NaN
# 19086       Somewhat agree     Somewhat agree             Agree
# 19087                  NaN                NaN               NaN
# 19091                Agree     Somewhat agree    Strongly agree
# 19096       Somewhat agree     Somewhat agree    Somewhat agree
# 19101                  NaN                NaN               NaN
#
#               Salary  ExpectedSalary  HigherEd
# 4                NaN             NaN         1
# 6                NaN             NaN         1
# 7                NaN             NaN         1
# 9                NaN             NaN         1
# 14     100000.000000             NaN         1
# 24               NaN             NaN         1
# 25     175000.000000             NaN         1
# 32               NaN             NaN         1
# 35               NaN             NaN         1
# 41               NaN             NaN         1
# 42               NaN             NaN         1
# 51               NaN             NaN         1
# 54      64516.129032             NaN         1
# 57      43010.752688             NaN         1
# 59               NaN             NaN         1
# 62               NaN             NaN         1
# 63               NaN             NaN         1
# 64      69892.473118             NaN         1
# 73               NaN             NaN         1
# 75      46236.559140             NaN         1
# 86               NaN             NaN         1
# 91               NaN             NaN         1
# 92               NaN             NaN         1
# 99     109400.000000             NaN         1
# 102     83870.967742             NaN         1
# 107              NaN             NaN         1
# 108              NaN             NaN         1
# 126     25806.451613             NaN         1
# 144              NaN             NaN         1
# 145              NaN             NaN         1
# ...              ...             ...       ...
# 19004    2040.740741             NaN         1
# 19007            NaN             NaN         1
# 19008            NaN             NaN         1
# 19009            NaN             NaN         1
# 19010            NaN             NaN         1
# 19011   31393.614888             NaN         1
# 19013            NaN             NaN         1
# 19018   34408.602151             NaN         1
# 19023            NaN             NaN         1
# 19027            NaN    14095.536413         1
# 19031            NaN             NaN         1
# 19032            NaN             NaN         1
# 19035            NaN             NaN         1
# 19046   43750.000000             NaN         1
# 19049            NaN             NaN         1
# 19051            NaN             NaN         1
# 19055  140000.000000             NaN         1
# 19059            NaN             NaN         1
# 19063            NaN             NaN         1
# 19064            NaN             NaN         1
# 19067            NaN             NaN         1
# 19071            NaN             NaN         1
# 19072            NaN             NaN         1
# 19073   87500.000000             NaN         1
# 19077            NaN             NaN         1
# 19086   80645.161290             NaN         1
# 19087            NaN             NaN         1
# 19091            NaN             NaN         1
# 19096            NaN             NaN         1
# 19101            NaN             NaN         1
#
# [4398 rows x 155 columns]

# %%
ed_1 = df[df['HigherEd'] == 1] # Subset df to only those with HigherEd of 1
ed_0 = df[df['HigherEd'] == 0] # Subset df to only those with HigherEd of 0


print(ed_1['HigherEd'][:5]) #Assure it looks like what you would expect
print(ed_0['HigherEd'][:5]) #Assure it looks like what you would expect
# Out:
# 4     1
# 6     1
# 7     1
# 9     1
# 14    1
# Name: HigherEd, dtype: int64
# 0    0
# 1    0
# 2    0
# 3    0
# 5    0
# Name: HigherEd, dtype: int64

# %%
#Check your subset is correct - you should get a plot that was created using pandas styling
#which you can learn more about here: https://pandas.pydata.org/pandas-docs/stable/style.html

ed_1_perc = clean_and_plot(ed_1, 'Higher Formal Education', plot=False)
ed_0_perc = clean_and_plot(ed_0, 'Max of Bachelors Higher Ed', plot=False)

comp_df = pd.merge(ed_1_perc, ed_0_perc, left_index=True, right_index=True)
comp_df.columns = ['ed_1_perc', 'ed_0_perc']
comp_df['Diff_HigherEd_Vals'] = comp_df['ed_1_perc'] - comp_df['ed_0_perc']
comp_df.style.bar(subset=['Diff_HigherEd_Vals'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_6bed1db2_29f9_11e9_89e6_0242ac120002row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 7.4%, #d65f5f 7.4%, #d65f5f 21.8%, transparent 21.8%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 21.8%, #5fba7d 21.8%, #5fba7d 32.0%, transparent 32.0%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 9.5%, #d65f5f 9.5%, #d65f5f 21.8%, transparent 21.8%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 17.2%, #d65f5f 17.2%, #d65f5f 21.8%, transparent 21.8%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 18.9%, #d65f5f 18.9%, #d65f5f 21.8%, transparent 21.8%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 21.8%, #5fba7d 21.8%, #5fba7d 22.0%, transparent 22.0%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.2%, #d65f5f 0.2%, #d65f5f 21.8%, transparent 21.8%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 21.8%, #5fba7d 21.8%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 21.8%, #5fba7d 21.8%, #5fba7d 30.2%, transparent 30.2%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 21.8%, transparent 21.8%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 10.4%, #d65f5f 10.4%, #d65f5f 21.8%, transparent 21.8%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 10.3%, #d65f5f 10.3%, #d65f5f 21.8%, transparent 21.8%);
#         }    #T_6bed1db2_29f9_11e9_89e6_0242ac120002row12_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 21.8%, #5fba7d 21.8%, #5fba7d 25.6%, transparent 25.6%);
#         }</style>
# <table id="T_6bed1db2_29f9_11e9_89e6_0242ac120002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ed_1_perc</th>
#         <th class="col_heading level0 col1" >ed_0_perc</th>
#         <th class="col_heading level0 col2" >Diff_HigherEd_Vals</th>
#     </tr>    <tr>
#         <th class="index_name level0" >method</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6bed1db2_29f9_11e9_89e6_0242ac120002level0_row0" class="row_heading level0 row0" >Take online courses</th>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row0_col0" class="data row0 col0" >0.205361</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row0_col1" class="data row0 col1" >0.21009</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row0_col2" class="data row0 col2" >-0.00472961</td>
#     </tr>    <tr>
#         <th id="T_6bed1db2_29f9_11e9_89e6_0242ac120002level0_row1" class="row_heading level0 row1" >Buy books and work through the exercises</th>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row1_col0" class="data row1 col0" >0.163579</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row1_col1" class="data row1 col1" >0.160257</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row1_col2" class="data row1 col2" >0.00332183</td>
#     </tr>    <tr>
#         <th id="T_6bed1db2_29f9_11e9_89e6_0242ac120002level0_row2" class="row_heading level0 row2" >Contribute to open source</th>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row2_col0" class="data row2 col0" >0.106031</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row2_col1" class="data row2 col1" >0.110053</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row2_col2" class="data row2 col2" >-0.00402243</td>
#     </tr>    <tr>
#         <th id="T_6bed1db2_29f9_11e9_89e6_0242ac120002level0_row3" class="row_heading level0 row3" >Part-time/evening courses</th>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row3_col0" class="data row3 col0" >0.101498</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row3_col1" class="data row3 col1" >0.103005</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row3_col2" class="data row3 col2" >-0.00150699</td>
#     </tr>    <tr>
#         <th id="T_6bed1db2_29f9_11e9_89e6_0242ac120002level0_row4" class="row_heading level0 row4" >Bootcamp</th>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row4_col0" class="data row4 col0" >0.0731179</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row4_col1" class="data row4 col1" >0.0740695</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row4_col2" class="data row4 col2" >-0.000951639</td>
#     </tr>    <tr>
#         <th id="T_6bed1db2_29f9_11e9_89e6_0242ac120002level0_row5" class="row_heading level0 row5" >Return to college</th>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row5_col0" class="data row5 col0" >0.0691762</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row5_col1" class="data row5 col1" >0.0691233</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row5_col2" class="data row5 col2" >5.29081e-05</td>
#     </tr>    <tr>
#         <th id="T_6bed1db2_29f9_11e9_89e6_0242ac120002level0_row6" class="row_heading level0 row6" >Conferences/meet-ups</th>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row6_col0" class="data row6 col0" >0.0670083</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row6_col1" class="data row6 col1" >0.0740695</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row6_col2" class="data row6 col2" >-0.00706122</td>
#     </tr>    <tr>
#         <th id="T_6bed1db2_29f9_11e9_89e6_0242ac120002level0_row7" class="row_heading level0 row7" >Master's degree</th>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row7_col0" class="data row7 col0" >0.0557745</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row7_col1" class="data row7 col1" >0.0302337</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row7_col2" class="data row7 col2" >0.0255408</td>
#     </tr>    <tr>
#         <th id="T_6bed1db2_29f9_11e9_89e6_0242ac120002level0_row8" class="row_heading level0 row8" >Get a job as a QA tester</th>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row8_col0" class="data row8 col0" >0.0508475</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row8_col1" class="data row8 col1" >0.0481019</td>
#         <td id="T_6bed1db2_29f9_11e9_89e6_0242ac120002row8_col2" class="data row8 col2" >0.00274557</td>
#     </tr>    <tr>
#         <th id="T_6bed1db2_29f9_11e

# %% [markdown]
# #### Question 5
#
# **5.** What can you conclude from the above plot?  Change the dictionary to mark **True** for the keys of any statements you can conclude, and **False** for any of the statements you cannot conclude.

# %%
sol = {'Everyone should get a higher level of formal education': False, 
       'Regardless of formal education, online courses are the top suggested form of education': True,
       'There is less than a 1% difference between suggestions of the two groups for all forms of education': True,
       'Those with higher formal education suggest it more than those who do not have it': False}

t.conclusions(sol)
# Out:
# That's not quite right.  Almost all are less than a 1% difference.  However, there is almost a 3% difference in those that
# Not quite.  Notice that those in the 1 category pushed earning a higher degree by approximately 2 times the other group.

# %% [markdown]
# This concludes another look at the way we could compare education methods by those currently writing code in industry.
